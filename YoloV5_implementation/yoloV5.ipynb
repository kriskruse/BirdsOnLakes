# %%
# !git clone https://github.com/ultralytics/yolov5  # clone repo
# %cd .\YoloV5_implementation\content\yolov5\
# !pip install -r yolov5/requirements.txt --user
# !pip install wandb

# %%
import torch
from IPython.display import Image  # for displaying images
print('Using torch %s %s' % (torch.__version__, torch.cuda.get_device_properties(0) if torch.cuda.is_available() else 'CPU'))
# Out:
# Using torch 1.10.1+cu113 _CudaDeviceProperties(name='NVIDIA GeForce GTX 1070', major=6, minor=1, total_memory=8191MB, multi_processor_count=15)

# %%
# !python yolov5/train.py --img 1008 --batch 8 --epochs 100 --data ./birds.yaml --cfg ./custom_yolov5s.yaml --weights ''

# %%
# !python yolov5/train.py --img 1008 --batch-size 10 --epochs 100 --data ./birds.yaml --weights yolov5s.pt
